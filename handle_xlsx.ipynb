# %%
from flowise import Flowise, PredictionData
import pandas as pd
import requests

# %%
# df = pd.read_excel("qa_par.xlsx",
#                    sheet_name="Sheet1",
#                    engine="openpyxl"
#                    )
# df.head()
# Out:
#                              Question  \
# 0      Chính sách học bổng của trường
# 1  Có bao nhiêu phương thức xét tuyển
# 2         Nộp hồ sơ đăng ký xét tuyển
# 3  Các khoản phí cần nộp khi nhập học
#
#                                          True answer  Real answer  Note  \
# 0  Chính sách học bổng\n1. Học bổng CMC Khai phón...          NaN   NaN
# 1  Năm 2024, Trường Đại học CMC xét tuyển theo 5 ...          NaN   NaN
# 2  Cách 1: Nộp hồ sơ trực tuyến.\nBước 1: Thí sin...          NaN   NaN
# 3  Khoản học phí tạm thu lần đầu: 11.054.520 đồng...          NaN   NaN
#
#    Status
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN

# %%
# df.loc[df["Status"].isna(), "Status"] = "Incomplete"
# df.head()
# Out:
# /tmp/ipykernel_88333/3569615800.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Incomplete' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df["Status"].isna(), "Status"] = "Incomplete"
#                              Question  \
# 0      Chính sách học bổng của trường
# 1  Có bao nhiêu phương thức xét tuyển
# 2         Nộp hồ sơ đăng ký xét tuyển
# 3  Các khoản phí cần nộp khi nhập học
#
#                                          True answer  Real answer  Note  \
# 0  Chính sách học bổng\n1. Học bổng CMC Khai phón...          NaN   NaN
# 1  Năm 2024, Trường Đại học CMC xét tuyển theo 5 ...          NaN   NaN
# 2  Cách 1: Nộp hồ sơ trực tuyến.\nBước 1: Thí sin...          NaN   NaN
# 3  Khoản học phí tạm thu lần đầu: 11.054.520 đồng...          NaN   NaN
#
#        Status
# 0  Incomplete
# 1  Incomplete
# 2  Incomplete
# 3  Incomplete

# %%
df = pd.read_csv("data/qa-pair.csv")
df.head()
# Out:
#                              Question  \
# 0      Chính sách học bổng của trường
# 1  Có bao nhiêu phương thức xét tuyển
# 2         Nộp hồ sơ đăng ký xét tuyển
# 3  Các khoản phí cần nộp khi nhập học
#
#                                          True answer  Real answer  Score  \
# 0  Chính sách học bổng\n1. Học bổng CMC Khai phón...          NaN    NaN
# 1  Năm 2024, Trường Đại học CMC xét tuyển theo 5 ...          NaN    NaN
# 2  Cách 1: Nộp hồ sơ trực tuyến.\nBước 1: Thí sin...          NaN    NaN
# 3  Khoản học phí tạm thu lần đầu: 11.054.520 đồng...          NaN    NaN
#
#    Note  Status
# 0   NaN     NaN
# 1   NaN     NaN
# 2   NaN     NaN
# 3   NaN     NaN

# %%
df.loc[df["Status"].isna(), "Status"] = "incomplete"
df.head()
# Out:
# /tmp/ipykernel_88333/4096478739.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'incomplete' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df["Status"].isna(), "Status"] = "incomplete"
#                              Question  \
# 0      Chính sách học bổng của trường
# 1  Có bao nhiêu phương thức xét tuyển
# 2         Nộp hồ sơ đăng ký xét tuyển
# 3  Các khoản phí cần nộp khi nhập học
#
#                                          True answer  Real answer  Score  \
# 0  Chính sách học bổng\n1. Học bổng CMC Khai phón...          NaN    NaN
# 1  Năm 2024, Trường Đại học CMC xét tuyển theo 5 ...          NaN    NaN
# 2  Cách 1: Nộp hồ sơ trực tuyến.\nBước 1: Thí sin...          NaN    NaN
# 3  Khoản học phí tạm thu lần đầu: 11.054.520 đồng...          NaN    NaN
#
#    Note      Status
# 0   NaN  incomplete
# 1   NaN  incomplete
# 2   NaN  incomplete
# ...

# %%
df.to_csv("data/qa-pair.csv")
